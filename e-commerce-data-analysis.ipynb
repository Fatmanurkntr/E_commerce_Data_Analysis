# %% [markdown]
# <h1 style="color: #907ad6">
#     E-Commerce Data Analysis 🛒💸🛍️</h1>

# %% [markdown]
# <img src="https://www.entreprendre.fr/wp-content/uploads/AdobeStock_234233410-1.jpg" alt="E-commerce dataset" width="600" height="600">

# %% [markdown]
#  <h1 style="color: #907ad6">
#     1. 🌟 Project Overview 🌟</h1>

# %% [markdown]
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#
# This project is built around analyzing various datasets from an e-commerce platform and examining the relationships between them. We combined three main datasets for a comprehensive analysis: **Sales Data**, **Customer Details**, and **Product Details**.
#
# - **Sales Data**: This dataset includes user interactions and purchasing behaviors on the platform. It tracks actions such as purchases, views, likes, and the timestamps for each event. Through this dataset, we can observe which products users interacted with on specific dates and how they completed their purchases. 🛒
#
# - **Customer Details**: This dataset provides demographic details of customers, such as age, gender, location, and details about the products they have purchased. It also includes factors like customer satisfaction, use of discounts, and payment methods. These details are valuable for understanding customer loyalty and designing marketing strategies. 🎯
#
# - **Product Details**: This dataset offers detailed information about the products sold. It contains product names, categories, list prices, seller information, whether the product is sold on Amazon, and product descriptions. This data is useful for analyzing product diversity and price fluctuations in the market. 🛍️
# </div>
# ️
# </div>

# %% [markdown]
#  <h1 style="color: #907ad6">
#     2. Data Loading 📥</h1>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#  Here, we load the dataset and prepare it for analysis.
# </div>

# %% [markdown]
# <h2 style="color: #907ad6">
#     2.1 Importing Libraries 📚</h2>
#
# <div style="background-color: #f0e6ff; padding: 10px; border-radius: 5px;">
# To start our analysis, we first need to import the essential libraries. Each library plays a specific role in our project, providing tools for data manipulation, visualization, and statistical analysis. Here's a quick overview of the libraries we'll be using:
#
# - **Pandas (`pd`)**: This is the backbone of data manipulation. It allows us to load, process, and explore our datasets easily. We'll be using it to create dataframes, handle missing values, and merge datasets. 🐼
#
# - **NumPy (`np`)**: This library adds powerful mathematical capabilities to our project. It is particularly useful for handling numerical data and performing complex computations efficiently. 🔢
#
# - **Matplotlib (`plt`)**: A versatile library for creating basic static visualizations. We will use it to create charts, plots, and graphs that help us understand the patterns and trends in our data. 📊
#
# - **Seaborn (`sns`)**: Built on top of Matplotlib, Seaborn makes statistical plots more appealing and easier to interpret. It’s perfect for creating heatmaps, pairplots, and other advanced visualizations. 🎨
#
# - **SciPy Stats (`stats`)**: This is our go-to library for statistical analysis. We will use it for performing hypothesis tests, calculating statistical measures, and understanding relationships between variables. 📈
#
# - **Plotly Express (`px`)**: A powerful interactive visualization library. We will use Plotly to create dynamic plots and graphs that allow for deeper insights by enabling us to zoom in and hover over data points for more details. 🌐
#
# Each of these libraries will help us dive deep into our e-commerce dataset and uncover valuable insights! Let's get started by loading them. 🚀
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import plotly.express as px
import warnings

warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")

# %% [markdown]
# <h2 style="color: #907ad6">2.2 Loading The Dataset 🔄</h2>
#
# <div style="background-color: #f0e6ff; padding: 10px; border-radius: 5px;">
# Now that we've imported our libraries, it's time to load the datasets we'll be analyzing. In this project, we have three primary datasets:
#
# 1. **Sales Data** 🛍️: This dataset contains information about user interactions with products on the platform. It includes details like product views, purchases, and timestamps.
#
# 2. **Customer Details** 🧑‍🤝‍🧑: This dataset provides demographic information about the customers, including age, gender, location, and their previous purchasing history.
#
# 3. **Product Details** 📦: This dataset includes detailed information about each product available on the platform, such as product names, categories, and prices.
#
# To load these datasets into our environment, we're using `pandas`'s `read_csv()` function, which reads the CSV files and converts them into dataframes. After loading, we print the first few rows of each dataset using the `head()` function to verify that everything is loaded correctly. 👀
#
# - **`sales_data`**: The data related to user interactions with products is loaded into the `sales_data` dataframe.
# - **`customer_details`**: Customer-related data is stored in the `customer_details` dataframe.
# - **`product_details`**: Product information is held in the `product_details` dataframe.
#
# This is an essential step because it ensures that the data has been imported correctly and allows us to get a quick look at the structure and contents of each dataset before diving into deeper analysis. Let's take a look at the first few rows! 🚀
# </div>

# %%
# Load the datasets
sales_data = pd.read_csv('/kaggle/input/e-commerece-sales-data-2024/E-commerece sales data 2024.csv')
customer_details = pd.read_csv('/kaggle/input/e-commerece-sales-data-2024/customer_details.csv')
product_details = pd.read_csv('/kaggle/input/e-commerece-sales-data-2024/product_details.csv')

# Display the first few rows of each dataset to verify loading
print("Sales Data:")
print(sales_data.head())
print("\nCustomer Details:")
print(customer_details.head())
print("\nProduct Details:")
print(product_details.head())
# Out:
# Sales Data:
#    user id                        product id Interaction type  \
# 0      1.0  4c69b61db1fc16e7013b43fc926e502d         purchase
# 1      2.0  66d49bbed043f5be260fa9f7fbff5957             view
# 2      3.0  2c55cae269aebf53838484b0d7dd931a             like
# 3      4.0  18018b6bc416dab347b1b7db79994afa             view
# 4      5.0  e04b990e95bf73bbe6a3fa09785d7cd0             like
#
#         Time stamp  Unnamed: 4
# 0  10/10/2023 8:00         NaN
# 1  11/10/2023 8:00         NaN
# 2  12/10/2023 8:00         NaN
# 3  13/10/2023 8:00         NaN
# 4  14/10/2023 8:00         NaN
#
# Customer Details:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# ...

# %% [markdown]
# <h2 style="color: #907ad6">2.3 Creating Missing Values (NaN) in the Dataset ⚠️</h2>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
# In this section, we simulate missing values in our datasets to make our analysis more challenging and realistic. Real-world data is often incomplete or messy, and dealing with **missing values** is an essential part of data preprocessing. 🧹
#
# ### The Approach 💡
# We define a function called `create_missing_values()` that introduces random missing values (NaN) into the datasets. Here's how it works:
#
# - **Step 1**: We first calculate the total number of cells in the dataset using `np.prod(data.shape)`, which multiplies the number of rows by the number of columns.
#
# - **Step 2**: We specify a `missing_rate`, which in this case is set to 5% (0.05). This rate determines what portion of the dataset will be turned into missing values.
#
# - **Step 3**: For each cell to be made missing, we randomly select a row and a column index and set the corresponding cell to `NaN` (Not a Number), representing a missing value in our dataset.
#
# ### Applying the Function 🚀
# We apply this function to all three datasets: `sales_data`, `customer_details`, and `product_details`, introducing 5% missing values into each one. This helps us test how robust our analysis methods are in handling incomplete data.
#
# - **`sales_data_missing`**: A new dataframe that contains the `sales_data` with 5% of its cells randomly turned into NaN values.
# - **`customer_details_missing`**: Similarly, this dataframe holds the `customer_details` with some random missing values.
# - **`product_details_missing`**: The `product_details` also undergoes the same treatment.
#
# ### Verifying Missing Values 🔍
# After creating the missing values, we use the `.isnull().sum()` method to count how many missing values are present in each column of the datasets. This gives us a clear idea of where the missing data is and how much of it exists.
#
# This step allows us to handle a more realistic scenario where data is incomplete, which is often the case in real-world applications. Let's dive into data cleaning and handling these missing values next! 🔧
# </div>

# %%
# Function: Creates random missing values with a specified rate
def create_missing_values(data, missing_rate=0.05):
    # Total number of cells in the dataset
    total_cells = np.prod(data.shape)  # np.product is replaced with np.prod
    
    # Number of cells to be left blank
    missing_cells = int(total_cells * missing_rate)
    
    # Randomly select row and column indices
    for _ in range(missing_cells):
        row = np.random.randint(0, data.shape[0])  # Random row selection
        col = np.random.randint(0, data.shape[1])  # Random column selection
        data.iat[row, col] = np.nan  # Set the selected cell to NaN

    return data

# Adding random missing values with a 5% rate to each dataset
sales_data_missing = create_missing_values(sales_data.copy(), missing_rate=0.05)
customer_details_missing = create_missing_values(customer_details.copy(), missing_rate=0.05)
product_details_missing = create_missing_values(product_details.copy(), missing_rate=0.05)

# Checking the datasets (shows the number of NaN values)
print("Sales Data with Missing Values:")
print(sales_data_missing.isnull().sum())

print("\nCustomer Details with Missing Values:")
print(customer_details_missing.isnull().sum())

print("\nProduct Details with Missing Values:")
print(product_details_missing.isnull().sum())
# Out:
# Sales Data with Missing Values:
# user id              442
# product id           440
# Interaction type     574
# Time stamp           431
# Unnamed: 4          3294
# dtype: int64
#
# Customer Details with Missing Values:
# Customer ID               183
# Age                       165
# Gender                    202
# Item Purchased            199
# Category                  159
# Purchase Amount (USD)     198
# Location                  218
# Size                      192
# Color                     188
# Season                    178
# Review Rating             207
# Subscription Status       196
# Shipping Type             220
# Discount Applied          193
# Promo Code Used           175
# Previous Purchases        192
# Payment Method            168
# Frequency of Purchases    191
# dtype: int64
#
# Product Details with Missing Values:
# Uniqe Id                   447
# Product Name               492
# Brand Name               10002
# Asin                     10002
# ...

# %% [markdown]
# <h1 style="color: #907ad6">3.Exploratory Data Analysis (EDA) 🔍</h1>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     In this step, we dive into **Exploratory Data Analysis (EDA)** to better understand the structure and patterns in our data. The goal is to explore the dataset, identify relationships between features, detect any issues such as missing values or outliers, and summarize the main characteristics of the data before performing further analyses or building machine learning models.
# </div>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     EDA involves various techniques that can be applied to gain insights into the dataset, including:
#     <p><strong>Descriptive Statistics:</strong> We summarize the main characteristics of the dataset using measures such as mean, median, standard deviation, and percentiles. These help in understanding the distribution and spread of data.</p>
#     <p><strong>Visualization:</strong> Visual tools like histograms, boxplots, and pair plots help us identify patterns, distributions, and potential outliers. These visuals make it easier to detect relationships between features.</p>
#     <p><strong>Correlation Analysis:</strong> We examine the correlation between different features in the dataset. This helps to identify which features are related to each other and which ones are more important for our analysis or model.</p>
#     <p><strong>Missing Data Analysis:</strong> We look for missing values in the dataset and apply appropriate techniques to handle them (e.g., filling, removing, or flagging). Addressing missing data is critical for ensuring that the analysis is reliable and complete.</p>
#     <p><strong>Outlier Detection:</strong> Identifying outliers helps ensure that the model is not influenced by extreme values. This can be done using visual tools or statistical techniques.</p>
# </div>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     Before diving deeper into EDA, it’s essential to get an initial look at the dataset:
#     <p><strong>Data Summary:</strong> We begin by examining the dataset’s shape (rows and columns) and types of data (numeric, categorical, etc.). This helps us understand what we are working with.</p>
#     <p><strong>First Few Rows:</strong> We inspect the first few rows of the data to get an overview of its structure and see if there are any immediate issues such as incorrect formatting or unexpected values.</p>
# </div>

# %% [markdown]
# <h2 style="color: #907ad6">3.1 Dropping Columns with 100% Missing Values 🗑️</h2>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
# In this step, we clean our data by **removing columns that have 100% missing values**. When a column is entirely empty (i.e., every value is `NaN`), it provides no useful information for analysis, so we can safely drop it. 🧹
#
# ### How It Works 🔍
# For each dataset (`sales_data`, `customer_details`, `product_details`), we check for columns where **all values are missing** using the `.isnull().all()` function. Then, we drop those columns using `dropna()` with the parameter `axis=1` to indicate we want to drop columns, not rows.
#
# ### Example 💡
# Here's what happens in each dataset:
# - **Sales Data**: We first check if there are any columns in `sales_data` that contain only missing values. If any exist, they are removed, and the names of these dropped columns are printed.
# - **Customer Details**: Similarly, columns in `customer_details` with all missing values are identified and removed.
# - **Product Details**: Lastly, the same process is applied to `product_details`.
#
# By removing these empty columns, we ensure that our datasets are leaner and contain only relevant data. This makes subsequent analyses more efficient and accurate. 🚀
#
# Now, let's check which columns were dropped and move forward with our cleaned datasets!
# </div>

# %%
# drop columns with 100% missing values and display the shape droped columns name
print("\n Sales Columns with 100% missing values: ", sales_data.columns[sales_data.isnull().all()])
sales_data.dropna(axis=1, how='all', inplace=True)

# drop columns with 100% missing values and display the shape droped columns name
print("\n Customer Details Columns with 100% missing values: ", customer_details.columns[customer_details.isnull().all()])
customer_details.dropna(axis=1, how='all', inplace=True)

# drop columns with 100% missing values and display the shape droped columns name
print("\n Product Details Columns with 100% missing values: ", product_details.columns[product_details.isnull().all()])
product_details.dropna(axis=1, how='all', inplace=True)
# Out:
#  Sales Columns with 100% missing values:  Index(['Unnamed: 4'], dtype='object')
#
#  Customer Details Columns with 100% missing values:  Index([], dtype='object')
#
#  Product Details Columns with 100% missing values:  Index(['Brand Name', 'Asin', 'List Price', 'Quantity', 'Sku', 'Stock',
#        'Product Details', 'Dimensions', 'Color', 'Ingredients',
#        'Direction To Use', 'Size Quantity Variant', 'Product Description'],
#       dtype='object')

# %% [markdown]
# <h3 style="color: #907ad6">Observations Based on the Output 📊</h3>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#
#
# ### Sales Data:
# - The column **`Unnamed: 4`** is completely missing, meaning that there is no data in this column. It is beneficial to remove this column from the dataset as it doesn’t provide any useful information.
# - The removal operation has already been performed in your code, so this column will no longer be present in the dataset.
#
# ### Customer Details:
# - There are **no columns** with 100% missing values in the `customer_details` dataset. This is a good thing because it means you don't have to worry about significant data loss in this dataset.
# - While there may still be missing data in some individual cells, all columns are populated with at least some data, ensuring that valuable information is retained for analysis.
#
# ### Product Details:
# - In the `product_details` dataset, there are several columns with **100% missing values**, such as **`Brand Name`**, **`Asin`**, **`List Price`**, **`Quantity`**, **`Sku`**, etc. These columns have been dropped from the dataset.
# - Since these columns contain no data, they wouldn’t contribute to any analysis or modeling process. Removing them helps in having a cleaner and more meaningful dataset for future steps in analysis.
# </div>

# %% [markdown]
# <h2 style="color: #907ad6"> 3.2 Checking for Missing Values in the Dataset 🚨</h2>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
# In this step, we are examining missing values (NaN) in each dataset (Sales, Customer, Product) to understand the completeness of the data. The **`isnull()`** function checks for missing values in each cell, and **`sum()`** aggregates the count of missing values in each column. This allows us to see how many missing values are present in each column.
#
# We use the following visualizations to make the missing values more apparent:
#
# - **Bar Plot**: A bar chart that shows the number of missing values for each column in the dataset.
# - **Heatmap**: A heatmap that highlights missing values in a color-coded manner.
# - **Missingno Visualization**: A visualization that provides a matrix view of missing values, which makes it easier to spot patterns of missingness across the dataset.
#
# The visualizations are generated for all three datasets:
# 1. **Sales Data**: Missing values in sales-related information.
# 2. **Customer Details**: Missing values in customer-related data.
# 3. **Product Details**: Missing values in product-related data.
# </div>

# %%
import missingno as msno

# Visualizing missing values with a bar plot
def plot_missing_values_bar(data, title="Missing Values Bar Plot"):
    missing_data_count = data.isnull().sum()  # Calculate the number of missing values in each column
    missing_data_count = missing_data_count[missing_data_count > 0]  # Only columns with missing values
    
    if missing_data_count.empty:
        print(f"{title}: No missing values found.")  # Print a message if no missing values
        return
    
    plt.figure(figsize=(12, 6))
    missing_data_count.plot(kind='bar', color='tomato')  # Bar plot
    plt.title(title)
    plt.xlabel('Columns')
    plt.ylabel('Number of Missing Values')
    plt.show()

# Visualizing missing values with a heatmap
def plot_missing_values_heatmap(data, title="Missing Values Heatmap"):
    plt.figure(figsize=(12, 8))
    sns.heatmap(data.isnull(), cbar=False, cmap='viridis')  # Displays missing values in yellow/green tones
    plt.title(title)
    plt.show()

# Visualizing missing values with missingno
def plot_missing_values_missingno(data, title="Missing Values with Missingno"):
    plt.figure(figsize=(12, 8))
    msno.matrix(data)  # Visualizes missing values
    plt.title(title)
    plt.show()

# Visualizing missing values for each dataset
def plot_missing_values_for_datasets():
    # Sales Data
    plot_missing_values_bar(sales_data, "Sales Data Missing Values Bar Plot")
    plot_missing_values_heatmap(sales_data, "Sales Data Missing Values Heatmap")
    plot_missing_values_missingno(sales_data, "Sales Data Missing Values with Missingno")

    # Customer Details
    plot_missing_values_bar(customer_details, "Customer Details Missing Values Bar Plot")
    plot_missing_values_heatmap(customer_details, "Customer Details Missing Values Heatmap")
    plot_missing_values_missingno(customer_details, "Customer Details Missing Values with Missingno")

    # Product Details
    plot_missing_values_bar(product_details, "Product Details Missing Values Bar Plot")
    plot_missing_values_heatmap(product_details, "Product Details Missing Values Heatmap")
    plot_missing_values_missingno(product_details, "Product Details Missing Values with Missingno")

# Running the visualization function
plot_missing_values_for_datasets()
# Out:
# Customer Details Missing Values Bar Plot: No missing values found.

# %% [markdown]
# <h2 style="color: #907ad6">3.3 Filling Missing Data 🛠️</h2>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
# Filling missing data is a critical step in data analysis and modeling. This process is essential to improve model accuracy, but the methods used may vary depending on the dataset. Below are the strategies we followed for each dataset, as well as explanations for why we did not fill the missing data in the Sales Data dataset.
#
# <h4>1. Customer Details Dataset</h4>
# In the Customer Details dataset, the following steps were taken to fill missing data:
# <ul>
#   <li><strong>Numerical Values</strong> (e.g., Age, Purchase Amount (USD)): Missing numerical values were filled with the mean of the existing values in the column. This approach is the most common method for filling missing values in numerical columns without disrupting the overall distribution of the data.</li>
#   <li><strong>Categorical Values</strong> (e.g., Gender, Item Purchased, Subscription Status): For categorical columns, missing values were filled with the mode (most frequent value) of the column. Since calculating the mean for categorical data does not make sense, using the most frequent value is more logical.</li>
# </ul>
#
# <h4>2. Product Details Dataset</h4>
# A similar approach was applied to the Product Details dataset:
# <ul>
#   <li><strong>Numerical Values</strong> (e.g., Selling Price, Shipping Weight): Missing values in numerical columns were filled with the mean. This allows for more meaningful evaluation of data such as product prices or weights.</li>
#   <li><strong>Categorical Values</strong> (e.g., Product Name, Category): Missing values in categorical columns were filled with the mode. The most frequent value of categorical data can logically complete missing information.</li>
# </ul>
#
# <h4>3. Sales Data Dataset</h4>
# The Sales Data dataset is the only dataset where missing data was not filled. There are several reasons for this:
# <ul>
#   <li><strong>Identity-Related Data</strong>: Columns such as user id and product id are unique identifiers for each entry, representing a person, product, or transaction. Filling missing values in these columns could disrupt the analysis process, as it is difficult to meaningfully impute these values. Especially since these columns are not used as key features for modeling, leaving them missing will not affect the analysis.</li>
#   <li><strong>Timestamp Data</strong>: Timestamp data, such as time-related information, requires a specific order and sequence. Filling missing values in timestamp columns could disrupt the time sequence, making it difficult to conduct accurate analysis. In time-series data, filling missing values is typically done in a way that does not affect the chronological order, so it was preferred to leave these columns with missing data.</li>
# </ul>
#
# <h4><strong>Why Wasn't the Sales Data Filled?</strong></h4>
# <ul>
#   <li><strong>Identity Data</strong>: user id, product id, and similar data are unique identifiers for each transaction. Missing values in these columns could lead to errors in analysis or modeling because it is challenging to impute them meaningfully. Filling them with incorrect values could mislead the model’s learning. Therefore, instead of filling missing data in these columns, it was preferred to ignore these missing values in the analysis process.</li>
#   <li><strong>Timestamp Data</strong>: Time-related data is associated with a specific order or time period. When the timestamp is missing, filling this data with methods like the mean or mode is not meaningful because it would disrupt the time sequence, hindering the accuracy of the analysis. Therefore, missing timestamp data was left as is to preserve the chronological order.</li>
# </ul>
# </div>

# %%
# For customer_details, fill missing numeric values with the mean and categorical values with the mode
for column in customer_details.columns:
    if customer_details[column].dtype == 'object':
        customer_details[column].fillna(customer_details[column].mode()[0], inplace=True)
    else:
        customer_details[column].fillna(customer_details[column].mean(), inplace=True)

# For product_details, assuming missing values in 'List Price' and other numeric fields, fill with mean
# and categorical fields with mode
for column in product_details.columns:
    if product_details[column].dtype == 'object':
        product_details[column].fillna(product_details[column].mode()[0], inplace=True)
    else:
        product_details[column].fillna(product_details[column].mean(), inplace=True)

# Summarizing key statistics for numerical and categorical variables
sales_summary = sales_data.describe(include=[np.number])
customer_summary = customer_details.describe(include=[np.number])

sales_cat_summary = sales_data.describe(include=[object])
customer_cat_summary = customer_details.describe(include=[object])
product_cat_summary = product_details.describe(include=[object])

# Displaying summaries
print("Sales Data Summary (Numerical):")
print(sales_summary)
print("\nSales Data Summary (Categorical):")
print(sales_cat_summary)

print("\nCustomer Details Summary (Numerical):")
print(customer_summary)
print("\nCustomer Details Summary (Categorical):")
print(customer_cat_summary)
# Out:
# Sales Data Summary (Numerical):
#            user id
# count  2999.000000
# mean   1500.000000
# std     865.881054
# min       1.000000
# 25%     750.500000
# 50%    1500.000000
# 75%    2249.500000
# max    2999.000000
#
# Sales Data Summary (Categorical):
#                               product id Interaction type       Time stamp
# count                               2999             2871             2999
# unique                              2999                3              366
# top     a2c6dd69f022a658c5bcc2b3b52970f2             like  10/10/2023 8:00
# freq                                   1             1145               21
#
# Customer Details Summary (Numerical):
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# ...

# %%
# check for missing values 
print("\n Sales Data Missing Values: ", sales_data.isnull().sum())
print("\n Product Details Missing Values: ", product_details.isnull().sum())
print("\n Customer Details Missing Values: ", customer_details.isnull().sum())
# Out:
#  Sales Data Missing Values:  user id             295
# product id          295
# Interaction type    423
# Time stamp          295
# dtype: int64
#
#  Product Details Missing Values:  Uniqe Id                 0
# Product Name             0
# Category                 0
# Upc Ean Code             0
# Selling Price            0
# Model Number             0
# About Product            0
# Product Specification    0
# Technical Details        0
# Shipping Weight          0
# Product Dimensions       0
# Image                    0
# Variants                 0
# Product Url              0
# Is Amazon Seller         0
# dtype: int64
#
#  Customer Details Missing Values:  Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# ...

# %% [markdown]
# <h3 style="color: #907ad6">Data Type Analysis 👩‍💻</h3>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     In this step, we analyze the data types of the columns in our dataset. This helps us understand the nature of each feature—whether it's categorical or numerical—and guides us in selecting the appropriate techniques for further analysis or modeling.
#     <p><strong>Identifying Categorical and Numerical Variables 📊</strong></p>
#     We begin by identifying and separating the categorical (object type) and numerical (number type) variables. This allows us to handle each type of data appropriately, applying specific methods to each.
#     <p><strong>Categorical Variables:</strong> These are variables that represent categories or labels. For example; <code>Gender</code>, <code>Item Purchased</code>, and <code>Subscription Status</code>.</p>
#      <p><strong>Numerical Variables:</strong> These are variables containing quantitative information. For example; <code>Age</code>, <code>Purchase Amount (USD)</code>, <code>Selling Price</code>, and <code>Shipping Weight</code>.</p>
# <p>We can use the following code to print the names of categorical and numerical columns for each dataset</p>
#
#
#  <p>In this code:</p>
#     <ul>
#         <li><strong>select_dtypes()</strong> method is used to select columns based on their data type.</li>
#         <li><strong>include=['object']</strong> selects categorical variables (such as strings or labels).</li>
#         <li><strong>include=['number']</strong> selects numerical variables (such as integers or floats).</li>
#         <li>The <strong>columns</strong> property returns the names of the columns for each data type.</li>
#     </ul>
#
# <p>By running this code, we can easily identify which columns are categorical and which are numerical. This will guide us in handling the data correctly during the analysis and modeling steps.</p>
# </div>

# %%
print(customer_details.select_dtypes(include=['object']).columns)
print(customer_details.select_dtypes(include=['number']).columns)

print(product_details.select_dtypes(include=['object']).columns)
print(product_details.select_dtypes(include=['number']).columns)
# Out:
# Index(['Gender', 'Item Purchased', 'Category', 'Location', 'Size', 'Color',
#        'Season', 'Subscription Status', 'Shipping Type', 'Discount Applied',
#        'Promo Code Used', 'Payment Method', 'Frequency of Purchases'],
#       dtype='object')
# Index(['Customer ID', 'Age', 'Purchase Amount (USD)', 'Review Rating',
#        'Previous Purchases'],
#       dtype='object')
# Index(['Uniqe Id', 'Product Name', 'Category', 'Upc Ean Code', 'Selling Price',
#        'Model Number', 'About Product', 'Product Specification',
#        'Technical Details', 'Shipping Weight', 'Product Dimensions', 'Image',
#        'Variants', 'Product Url', 'Is Amazon Seller'],
#       dtype='object')
# Index([], dtype='object')

# %%
# check for missing values 
print("\n Sales Data Missing Values: ", sales_data.isnull().sum())
print("\n Product Details Missing Values: ", product_details.isnull().sum())
print("\n Customer Details Missing Values: ", customer_details.isnull().sum())
# Out:
#  Sales Data Missing Values:  user id             295
# product id          295
# Interaction type    423
# Time stamp          295
# dtype: int64
#
#  Product Details Missing Values:  Uniqe Id                 0
# Product Name             0
# Category                 0
# Upc Ean Code             0
# Selling Price            0
# Model Number             0
# About Product            0
# Product Specification    0
# Technical Details        0
# Shipping Weight          0
# Product Dimensions       0
# Image                    0
# Variants                 0
# Product Url              0
# Is Amazon Seller         0
# dtype: int64
#
#  Customer Details Missing Values:  Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# ...

# %% [markdown]
# <h2 style="color: #907ad6">3.4 Data Distribution and Visualization 📊</h2>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     In this section, we focus on visualizing the distribution of data within the dataset. Visualizations, such as pie charts, bar charts, and histograms, are useful tools for understanding the proportions and patterns of data.
#
# <p><strong>Pie Chart for Proportion of Products Sold by Amazon</strong></p>
#     We begin by using a pie chart to visualize the distribution of products sold by Amazon. The code below accomplishes this task by plotting a pie chart based on the "Is Amazon Seller" column from the <strong>product_details</strong> dataset.</p>
#
# <p><strong>Explanation of the Code:</strong></p>
#     <p>The <strong>import matplotlib.pyplot as plt</strong> and <strong>import seaborn as sns</strong> commands import the necessary libraries for creating visualizations.</p>
#
# <p>The <strong>plt.figure(figsize=(8, 6))</strong> command sets the figure size for the plot, ensuring that the chart is large enough to display clearly. The <strong>product_details['Is Amazon Seller'].value_counts()</strong> part counts the occurrences of each unique value in the "Is Amazon Seller" column, which represents whether a product is sold by Amazon or not.</p>
#
#  <p>The <strong>plot(kind='pie', autopct='%1.1f%%')</strong> command creates the pie chart, where:
#     <strong>kind='pie'</strong> specifies the type of plot as a pie chart, and
#     <strong>autopct='%1.1f%%'</strong> adds percentage labels on the slices with one decimal place.</p>
#
#  <p>The <strong>plt.title('Proportion of Products Sold by Amazon')</strong> adds a title to the chart, making it clear what the chart represents.</p>
#
#  <p>Finally, the <strong>plt.show()</strong> command displays the chart. The pie chart will show the proportion of products sold by Amazon compared to those sold by other sellers, helping us visually understand the distribution of this categorical variable.</p>
# </div>

# %%
plt.figure(figsize=(8, 6))
product_details['Is Amazon Seller'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Proportion of Products Sold by Amazon')
plt.show()

# %%
sns.pairplot(customer_details[['Age', 'Purchase Amount (USD)', 'Review Rating']])
plt.suptitle('Pairplot of Age, Purchase Amount, and Review Rating', y=1.02)
plt.show()

# %%
plt.figure(figsize=(8, 6))
customer_details['Subscription Status'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#99ff99'])
plt.title('Proportion of Subscription Status')
plt.ylabel('')
plt.show()

# %% [markdown]
# <h2 style="color: #907ad6">3.5 Combining Datasets and Analyzing Relationships 🔗</h2>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>In this step, we focus on examining the relationships between three different datasets by performing a merge operation. This process allows us to create a single, comprehensive dataset that includes sales, customer, and product information. Here's how the process unfolds:</tionable insights.</p>
# </div>

# %% [markdown]
# <h3 style="color: #907ad6">First Merge - sales_data and customer_details:</h3>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>In this step, we are merging the <strong>sales_data</strong> and <strong>customer_details</strong> datasets. The merge operation is based on matching the 'user id' column in <strong>sales_data</strong> with the 'Customer ID' column in <strong>customer_details</strong>. The <strong>how='inner'</strong> parameter ensures that only the rows with matching 'user id' and 'Customer ID' values in both datasets are merged. This means that only customers present in both datasets, along with their sales data, will be merged. As a result, a new dataframe called <strong>sales_customer</strong> is created, which contains both customer and sales information.</p>
# </div>

# %%
sales_customer = pd.merge(sales_data, customer_details, left_on='user id', right_on='Customer ID', how='inner')

# %% [markdown]
# <h3 style="color: #907ad6">Second Merge - sales_customer and product_details:</h3>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>In this step, we are merging the <strong>sales_customer</strong> and <strong>product_details</strong> datasets. The merge operation is performed based on matching the 'product id' column in <strong>sales_customer</strong> with the 'Uniqe Id' column in <strong>product_details</strong>. Again, using the <strong>how='inner'</strong> parameter ensures that only the rows with matching 'product id' and 'Uniqe Id' values in both datasets are merged.</p
#     <p>As a result, a new dataframe called <strong>sales_customer_product</strong> is created. This dataframe contains sales data, customer information, and product details, allowing for a comprehensive view of the sales transactions.</p>
# </div>

# %%
sales_customer_product = pd.merge(sales_customer, product_details, left_on='product id', right_on='Uniqe Id', how='inner')

# %% [markdown]
# <h3 style="color: #907ad6">Viewing the Columns of the Merged DataFrame:</h3>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>This line of code prints all the column names from the <strong>sales_customer_product</strong> dataframe. By doing so, we can examine the names of the columns that have been merged from both datasets, providing us with a comprehensive view of the data structure.</p>
# </div>

# %%
print("Columns in sales_customer_product DataFrame: ", sales_customer_product.columns)
# Out:
# Columns in sales_customer_product DataFrame:  Index(['user id', 'product id', 'Interaction type', 'Time stamp',
#        'Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category_x',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases', 'Uniqe Id', 'Product Name',
#        'Category_y', 'Upc Ean Code', 'Selling Price', 'Model Number',
#        'About Product', 'Product Specification', 'Technical Details',
#        'Shipping Weight', 'Product Dimensions', 'Image', 'Variants',
#        'Product Url', 'Is Amazon Seller'],
#       dtype='object')

# %%
print(sales_customer_product.isnull().sum())
# Out:
# user id                     0
# product id                  0
# Interaction type          128
# Time stamp                  0
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category_x                  0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Payment Method              0
# Frequency of Purchases      0
# Uniqe Id                    0
# Product Name                0
# Category_y                  0
# Upc Ean Code                0
# Selling Price               0
# Model Number                0
# About Product               0
# Product Specification       0
# Technical Details           0
# ...

# %%
# Check the unique values in the 'Interaction type' column
print(sales_customer_product['Interaction type'].unique())
# Out:
# ['purchase' 'view' 'like']

# %%
# Fill missing values in the 'Interaction type' column with the most frequent value (mode)
sales_customer_product['Interaction type'].fillna(sales_customer_product['Interaction type'].mode()[0], inplace=True)

# %%
# Check if there are any missing values
print(sales_customer_product['Interaction type'].isnull().sum())
# Out:
# 0

# %%
print(sales_customer_product.isnull().sum())
# Out:
# user id                   0
# product id                0
# Interaction type          0
# Time stamp                0
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category_x                0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# Uniqe Id                  0
# Product Name              0
# Category_y                0
# Upc Ean Code              0
# Selling Price             0
# Model Number              0
# About Product             0
# Product Specification     0
# Technical Details         0
# Shipping Weight           0
# Product Dimensions        0
# ...

# %% [markdown]
# <h1 style="color: #907ad6">4. Statistical Analysis & Visualization 📊</h1>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>This section focuses on conducting statistical analysis and visualizations to explore patterns and relationships within the dataset. The following steps are typically included in this phase:</p>
# <p><strong>Statistical Measures:</strong> Basic statistical measures of the dataset, such as mean, median, standard deviation, etc., are calculated and interpreted. These measures help us understand the central tendency, spread, and distribution of the data.</p>
# <p><strong>Relationships Between Variables:</strong> Techniques like correlation analysis are used to explore the relationships between different variables. This helps identify which variables are correlated with each other and which ones might be important for modeling.</p>
# <p><strong>Visualization:</strong> Various visualization techniques (box plots, scatter plots, correlation matrices, etc.) are used to analyze the data in more detail. These visualizations provide insights into the underlying patterns in the dataset and are essential for identifying trends and outliers.</p>
# <p>These steps are essential for gaining a deeper understanding of the dataset before moving on to the modeling phase. They help in identifying key variables, potential relationships, and overall data distribution.</p>
# </div>

# %%
# Calculate statistical measures
statistics = sales_customer_product.describe()

# View mean, median, mode, and standard deviation
mean_value = sales_customer_product['Purchase Amount (USD)'].mean()  # Mean
median_value = sales_customer_product['Purchase Amount (USD)'].median()  # Median
mode_value = sales_customer_product['Purchase Amount (USD)'].mode()[0]  # Mode
std_dev_value = sales_customer_product['Purchase Amount (USD)'].std()  # Standard deviation

# Minimum and maximum values
min_value = sales_customer_product['Purchase Amount (USD)'].min()
max_value = sales_customer_product['Purchase Amount (USD)'].max()

# Print the results
print("Statistical Measures:")
print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Mode: {mode_value}")
print(f"Standard Deviation: {std_dev_value}")
print(f"Minimum Value: {min_value}")
print(f"Maximum Value: {max_value}")
print("\nDescribe Method - All Statistical Measures:")
print(statistics)
# Out:
# Statistical Measures:
# Mean: 59.653217739246415
# Median: 60.0
# Mode: 36
# Standard Deviation: 23.800239839699593
# Minimum Value: 20
# Maximum Value: 100
#
# Describe Method - All Statistical Measures:
#            user id  Customer ID          Age  Purchase Amount (USD)  \
# count  2999.000000  2999.000000  2999.000000            2999.000000
# mean   1500.000000  1500.000000    44.064021              59.653218
# std     865.881054   865.881054    15.284927              23.800240
# min       1.000000     1.000000    18.000000              20.000000
# 25%     750.500000   750.500000    31.000000              38.000000
# 50%    1500.000000  1500.000000    44.000000              60.000000
# 75%    2249.500000  2249.500000    57.000000              81.000000
# max    2999.000000  2999.000000    70.000000             100.000000
#
#        Review Rating  Previous Purchases
# count    2999.000000         2999.000000
# mean        3.749783           25.647216
# ...

# %% [markdown]
# <h2 style="color: #907ad6">4.1 Statistical Functions and Interpretation 📊</h2>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>This section explains the statistical functions used to calculate various measures and how to interpret them:</p>
#
# <p><strong>mean()</strong> function calculates the average (mean) of the data.</p>
# <p><strong>median()</strong> function calculates the median value, which is the middle value of the data set when arranged in order.</p>
#  <p><strong>mode()</strong> function calculates the mode of the data, i.e., the most frequent value. If there are multiple modes, it returns the first one.</p>
#  <p><strong>std()</strong> function calculates the standard deviation, which measures the spread or dispersion of the data.</p>
#  <p><strong>min()</strong> and <strong>max()</strong> functions return the minimum and maximum values of the data, respectively.</p>
#
#  <p><strong>describe() Method:</strong> The <strong>describe()</strong> function provides a more comprehensive statistical summary of the numeric columns in the dataset. It includes information such as the mean, standard deviation, minimum, maximum, and quartiles of the data.</p>
#
# <p><strong>Interpreting Statistical Measures:</strong></p>
# <p><strong>Mean:</strong> If the mean is significantly different from the median, it suggests that the data may not be symmetrically distributed (e.g., a skewed distribution).</p>
#     <p><strong>Median:</strong> The median represents the middle value of the data. If there is a large difference between the median and the mean, the data might be skewed.</p>
#     <p><strong>Standard Deviation:</strong> A high standard deviation means the data is spread out over a wide range, whereas a low standard deviation indicates that the data is clustered in a narrow range.</p>
#     <p><strong>Minimum and Maximum:</strong> These values show the range of the dataset, indicating how spread out the data is.</p>
#
# <p>By using these statistical functions and interpretations, we can gain a better understanding of the data distribution and detect any skewness or unusual patterns in the data.</p>
# </div>

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=sales_customer_product, x="Age", kde=True)
plt.title("Distribution of Customer Age")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.figure(figsize=(8, 6))
sns.countplot(data=sales_customer_product, x="Gender")
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")

plt.figure(figsize=(8, 6))
sns.histplot(data=sales_customer_product, x="Purchase Amount (USD)", kde=True)
plt.title("Distribution of Purchase Amount")
plt.xlabel("Purchase Amount (USD)")
plt.ylabel("Frequency")

plt.figure(figsize=(8, 6))
sns.countplot(data=sales_customer_product, x="Location")
plt.title("Location Distribution")
plt.xlabel("Location")
plt.ylabel("Count")
plt.xticks(rotation=90)

plt.figure(figsize=(8, 6))
sns.countplot(data=sales_customer_product, x="Category_x")
plt.title("Category Distribution")
plt.xlabel("Category")
plt.ylabel("Count")

plt.figure(figsize=(8, 6))
sns.histplot(data=sales_customer_product, x="Review Rating", kde=True)
plt.title("Distribution of Review Rating")
plt.xlabel("Review Rating")
plt.ylabel("Frequency")
plt.xticks(rotation=45)

plt.figure(figsize=(8, 6))
sns.countplot(data=sales_customer_product, x="Subscription Status")
plt.title("Subscription Status Distribution")
plt.xlabel("Subscription Status")
plt.ylabel("Count")

plt.figure(figsize=(8, 6))
sns.countplot(data=sales_customer_product, x="Shipping Type")
plt.title("Shipping Type Distribution")
plt.xlabel("Shipping Type")
plt.ylabel("Count")
plt.xticks(rotation=45)

plt.figure(figsize=(8, 6))
sns.countplot(data=sales_customer_product, x="Discount Applied")
plt.title("Discount Applied Distribution")
plt.xlabel("Discount Applied")
plt.ylabel("Count")

plt.figure(figsize=(8, 6))
sns.countplot(data=sales_customer_product, x="Promo Code Used")
plt.title("Promo Code Used Distribution")
plt.xlabel("Promo Code Used")
plt.ylabel("Count")

plt.figure(figsize=(8, 6))
sns.countplot(data=sales_customer_product, x="Payment Method")
plt.title("Payment Method Distribution")
plt.xlabel("Payment Method")
plt.ylabel("Count")
plt.xticks(rotation=45)

plt.figure(figsize=(8, 6))
sns.countplot(data=sales_customer_product, x="Frequency of Purchases")
plt.title("Frequency of Purchases Distribution")
plt.xlabel("Frequency of Purchases")
plt.ylabel("Count")
plt.xticks(rotation=45)

plt.figure(figsize=(8, 6))
# sales_data['Interaction type'].value_counts().plot(kind='bar', color='purple')
sns.histplot(data=sales_customer_product, x="Interaction type", kde=True)
plt.title('Distribution of Type of Interaction')
plt.xlabel('Type of Interaction')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# <h2 style="color: #907ad6">Visualizing Data Distributions & Relationships 📊</h2>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>This section focuses on using various plots to visualize the distributions and relationships of different features in our dataset. Each plot helps us understand the distribution and relationships within specific features. Here’s an overview of the visualizations used:</p>
#
# <p><strong>Customer Age Distribution:</strong> A histogram and KDE (Kernel Density Estimation) were used to visualize the distribution of the Age variable. This plot shows how the age distribution looks and which age ranges are more prevalent.</p>
#
# <p><strong>Gender Distribution:</strong> A countplot was used to visualize the categorical data of the Gender variable. This plot allows us to compare the number of male and female customers.</p>
#
# <p><strong>Purchase Amount Distribution:</strong> A histogram and KDE were used to visualize the continuous data of the Purchase Amount (USD) variable. This helps us visually analyze the average purchase amounts and their distribution.</p>
#
# <p><strong>Location Distribution:</strong> A countplot was used to visualize the categorical data of the Location variable. This plot shows which regions have the highest concentration of customers.</p>
#
# <p><strong>Product Category Distribution:</strong> A countplot was used to visualize the categorical distribution of the Category_x (Product Category) variable. This helps us understand which product categories are more popular among customers.</p>
#
#  <p><strong>Review Rating Distribution:</strong> A histogram and KDE were used to visualize the distribution of the Review Rating variable. This plot shows how customer ratings are distributed and their trends.</p>
#
# <p><strong>Subscription Status Distribution:</strong> A countplot was used to visualize the distribution of the Subscription Status variable. This helps us understand the proportion of customers in different subscription statuses.</p>
#
# <p><strong>Shipping Type Distribution:</strong> A countplot was used to visualize the distribution of the Shipping Type variable. This plot shows the frequency of different shipping methods.</p>
#
# <p><strong>Discount Applied Distribution:</strong> The categorical distribution of the Discount Applied variable was visualized using a countplot. This plot shows the frequency of products with discounts.</p>
#
# <p><strong>Promo Code Used Distribution:</strong> A countplot was used to visualize the distribution of the Promo Code Used variable. This shows how often promo codes were used during purchases.</p>
#
# <p><strong>Payment Method Distribution:</strong> A countplot was used to visualize the distribution of the Payment Method variable. This plot reveals the frequency of each payment method used by customers.</p>
#
# <p><strong>Frequency of Purchases Distribution:</strong> A countplot was used to visualize the distribution of the Frequency of Purchases variable. This gives insights into how often customers make purchases.</p>
#
# <p><strong>Interaction Type Distribution:</strong> A histogram and KDE were used to visualize the distribution of the Interaction type variable. This plot shows the frequency of different interaction types between customers and the service.</p>
#
#  <p>These visualizations are helpful for analyzing the different features of the dataset and provide a foundation for further analyses.</p>
# </div>

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=sales_customer_product['Purchase Amount (USD)'])
plt.title('Box Plot of Purchase Amount (USD)')
plt.xlabel('Purchase Amount (USD)')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=sales_customer_product['Purchase Amount (USD)'])
plt.title('Violin Plot of Purchase Amount (USD)')
plt.xlabel('Purchase Amount (USD)')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=sales_customer_product, x="Age", y="Purchase Amount (USD)")
plt.title("Scatter Plot of Purchase Amount vs. Age")
plt.xlabel("Age")
plt.ylabel("Purchase Amount (USD)")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=sales_customer_product, x="Gender", y="Purchase Amount (USD)")
plt.title("Box Plot of Purchase Amount by Gender")
plt.xlabel("Gender")
plt.ylabel("Purchase Amount (USD)")
plt.show()

# %% [markdown]
# <h2 style="color: #907ad6">4.2 Time Series Analysis with Time Stamp ⏳</h2>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>This section focuses on analyzing time series data, typically based on the <strong>time stamp</strong> column. Time series analysis allows us to identify trends, patterns, and changes in data over time.</p>
#
# <p><strong>Time-based Analysis:</strong> By utilizing the time stamp column, we can analyze events that occur at specific intervals, such as the number of purchases made each day or every hour. This type of analysis is crucial for understanding how customer behavior varies over time and can help us identify seasonality, trends, and peak times for purchases.</p>
#
# <p><strong>Applications of Time Series Analysis:</strong> Time series data can provide insights into customer purchasing behaviors over time, the effect of specific events (like promotions) on sales, and help forecast future demand. We can also detect unusual patterns or anomalies in customer activity that may require further investigation.</p>
#
#    <p>Overall, time series analysis based on time stamp data plays a vital role in understanding temporal patterns and improving decision-making related to sales, marketing, and product strategies.</p>
# </div>

# %%
# Convert the date format in the 'Time stamp' column by specifying the format
sales_customer_product['Time stamp'] = pd.to_datetime(sales_customer_product['Time stamp'], format='%d/%m/%Y %H:%M')

# Check if the conversion was successful
print(sales_customer_product['Time stamp'].head())
# Out:
# 0   2023-10-10 08:00:00
# 1   2023-10-11 08:00:00
# 2   2023-10-12 08:00:00
# 3   2023-10-13 08:00:00
# 4   2023-10-14 08:00:00
# Name: Time stamp, dtype: datetime64[ns]

# %% [markdown]
# <h3 style="color: #907ad6">DateTime Format Conversion with %d/%m/%Y %H:%M 🕒</h3>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>The format <strong>%d/%m/%Y %H:%M</strong> represents the day, month, year, hour, and minute, respectively. This allows us to convert the <strong>Time stamp</strong> column correctly into a <strong>datetime</strong> format, enabling better analysis and manipulation of time-related data.</p>
#
# <p><strong>Handling Different Date Formats:</strong> If the date formats in the dataset vary, you can use the <strong>errors='coerce'</strong> parameter during conversion. This will ensure that any invalid date entries are marked as <strong>NaT (Not a Time)</strong>, which helps prevent errors and allows for cleaner data processing.</p>
#
# <p>Using the appropriate date format and error handling ensures that time-based data is accurately processed and ready for analysis, making it easier to conduct time series analysis, identify trends, and visualize temporal patterns.</p>
# </div>

# %%
sales_customer_product['Time stamp'] = pd.to_datetime(sales_customer_product['Time stamp'], format='%d/%m/%Y %H:%M', errors='coerce')

# %% [markdown]
# <h3 style="color: #907ad6">a. Purchase Amount Change Over Time 📈</h3>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>This analysis focuses on how the <strong>Purchase Amount</strong> varies over time. By examining the <strong>Time Stamp</strong> column and aggregating the purchase amounts by a specific time unit (e.g., daily, weekly, or monthly), we can identify trends, seasonal patterns, and any significant changes in purchasing behavior.</p>
#
# </div>

# %%
import matplotlib.pyplot as plt

# Convert the date format in the 'Time stamp' column by specifying the format
sales_customer_product['Time stamp'] = pd.to_datetime(sales_customer_product['Time stamp'], format='%d/%m/%Y %H:%M', errors='coerce')

# Group the data by date and calculate the total purchase amount (daily or monthly)
daily_sales = sales_customer_product.groupby(sales_customer_product['Time stamp'].dt.date)['Purchase Amount (USD)'].sum()

# Time series plot
plt.figure(figsize=(10, 6))
daily_sales.plot()
plt.title('Total Purchase Amount Over Time')
plt.xlabel('Date')
plt.ylabel('Total Purchase Amount (USD)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# <h3 style="color: #907ad6">b. Distribution of Interaction Types Over Time (Line Chart or Area Chart) 📊</h3>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>This analysis focuses on examining how different <strong>interaction types</strong> (e.g., "purchase", "view", "like") change over time. By visualizing the distribution of these interactions across a specific time period (such as daily, weekly, or monthly), we can identify trends and patterns in user behavior.</ds.</p>
# </div>

# %%
# Group the number of interactions by date and interaction type
interaction_sales_over_time = sales_customer_product.groupby([sales_customer_product['Time stamp'].dt.date, 'Interaction type']).size().unstack(fill_value=0)

# Line chart
interaction_sales_over_time.plot(kind='line', figsize=(10, 6), marker='o')
plt.title('Interaction Types Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Interactions')
plt.xticks(rotation=45)
plt.legend(title='Interaction Type')
plt.show()

# %% [markdown]
# <h3 style="color: #907ad6">c. Monthly Purchase Amount Trends 📅</h3>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>This analysis focuses on examining the <strong>monthly purchase trends</strong> by aggregating the purchase amount based on the <strong>Time Stamp</strong> column. By grouping the data by month, you can observe fluctuations in sales over time, helping to identify seasonal patterns or specific months with higher or lower sales activity.</es.</p>
# </div>

# %%
# Group the total purchase amount by month
monthly_sales = sales_customer_product.groupby(sales_customer_product['Time stamp'].dt.to_period('M'))['Purchase Amount (USD)'].sum()

# Line chart
plt.figure(figsize=(10, 6))
monthly_sales.plot()
plt.title('Total Purchase Amount by Month')
plt.xlabel('Month')
plt.ylabel('Total Purchase Amount (USD)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h3 style="color: #907ad6">d. Customer Purchase Behavior Over Time (Heatmap) 🔥</h3>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>This analysis focuses on visualizing the <strong>change in customer purchase behavior over time</strong> using a <strong>heatmap</strong>. A heatmap is an effective way to display the density of purchases based on the time of day and day of the week, providing insights into when customers are most active in making purchases.</p>
#     </div>

# %%
# Group the daily sales by hour
sales_customer_product['Hour'] = sales_customer_product['Time stamp'].dt.hour
sales_customer_product['Day'] = sales_customer_product['Time stamp'].dt.day_name()

hourly_sales = sales_customer_product.groupby(['Day', 'Hour']).size().unstack(fill_value=0)

# Heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(hourly_sales, cmap="YlGnBu", annot=True, fmt='d')
plt.title('Hourly Purchase Activity by Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Day of the Week')
plt.show()

# %% [markdown]
# <h3 style="color: #907ad6">Change in Average Purchase Amount Per Customer Over Time 📊</h3>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>This analysis examines the changes in the average purchase amount per customer over time. Understanding how customer behavior evolves over time is crucial for evaluating the effectiveness of marketing strategies and analyzing customer loyalty. Such an analysis can help us identify time periods when customers are spending more and gain insights into overall shopping habits and trends.</p>
# </div>

# %%
# Group the average purchase amount per customer over time
avg_purchase_per_customer = sales_customer_product.groupby(sales_customer_product['Time stamp'].dt.date).apply(
    lambda x: x.groupby('Customer ID')['Purchase Amount (USD)'].sum().mean())

# Line chart
plt.figure(figsize=(10, 6))
avg_purchase_per_customer.plot()
plt.title('Average Purchase Amount per Customer Over Time')
plt.xlabel('Date')
plt.ylabel('Average Purchase Amount (USD)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h2 style="color: #907ad6">Distribution of Purchase Amounts by Hour of the Day (Box Plot) ⏰</h2>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>This analysis uses a box plot to examine the distribution of purchase amounts based on the hour of the day. It helps to identify peak shopping hours and the spread of purchase values across different times. By understanding when customers are more likely to make purchases, businesses can optimize their marketing strategies and focus their efforts during high-traffic periods.</p>
# </div>

# %%
# Group the data by the hour of the day
sales_customer_product['Hour'] = sales_customer_product['Time stamp'].dt.hour

# Box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Hour', y='Purchase Amount (USD)', data=sales_customer_product)
plt.title('Purchase Amount Distribution by Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Purchase Amount (USD)')
plt.show()

# %% [markdown]
# <h2 style="color: #907ad6">Changes in User Interactions Over Time (Stacked Area Chart) 📊</h2>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>A stacked area chart is used to visualize the changes in user interactions over time. This type of chart helps in understanding how different types of interactions (such as "purchase", "view", "like") evolve over a given period. By analyzing these trends, businesses can gain insights into shifting user behaviors and plan targeted strategies for engaging their audience more effectively.</p>
# </div>

# %%
# Grouping interaction types by time
interaction_sales = sales_customer_product.groupby([sales_customer_product['Time stamp'].dt.date, 'Interaction type']).size().unstack(fill_value=0)

# Stacked area chart
interaction_sales.plot(kind='area', figsize=(10, 6), alpha=0.5)
plt.title('Interaction Types Over Time (Stacked)')
plt.xlabel('Date')
plt.ylabel('Number of Interactions')
plt.show()

# %% [markdown]
# <h2 style="color: #907ad6">4.3 Sales Metrics Analysis by Interaction Types 📊</h2>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>These graphs visualize how different "Interaction types" relate to various sales metrics. Each graph demonstrates the relationship between a specific metric (such as "Purchase Amount (USD)", "Age", "Discount Applied") and "Interaction type" over time.</p>
#     <h4>Operations Performed:</h4>
#     <ul>
#         <li><strong>Data Preparation:</strong> We analyzed the relationship between the "Interaction type" column and other columns such as "Purchase Amount (USD)", "Age", "Discount Applied", "Frequency of Purchases", "Review Rating", and "Shipping Weight".</li>
#         <li><strong>Data Visualization:</strong> Line charts were created for each interaction type. The Y-axis represents the relevant metric, and the X-axis shows the "Interaction type" values.</li>
#         <li><strong>Readability:</strong> Font sizes in the graphs were reduced to prevent overlapping of labels. Additionally, X-axis labels were rotated by 45 degrees for better visibility.</li>
#         <li><strong>Layout Adjustment:</strong> The layout of the graphs was optimized using the <code>tight_layout()</code> function for a cleaner presentation.</li>
#     </ul>
#     <p>These visualizations are valuable for understanding the impact of different interaction types on each sales metric. The trends in each graph reveal the variations across interaction types, providing insights into user behavior analysis.</p>
# </div>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#adjust the graphic dimensions
plt.figure(figsize=(12, 10))

# 1. Grafik: Interaction type vs Purchase Amount (USD)
plt.subplot(3, 2, 1)  # 3 satır, 2 sütunluk bir yapıdaki 1. grafik
sns.lineplot(x="Interaction type", y="Purchase Amount (USD)", data=sales_customer_product, color='blue')
plt.title('Interaction type vs Purchase Amount (USD)', fontsize=14)
plt.xticks(rotation=45, fontsize=10)  # x ekseni etiketleri döndürülür ve yazı boyutu küçültülür
plt.yticks(fontsize=10)  # y ekseni etiketlerinin yazı boyutu küçültülür

# 2. Grafik: Interaction type vs Age
plt.subplot(3, 2, 2)  # 3 satır, 2 sütunluk bir yapıdaki 2. grafik
sns.lineplot(x="Interaction type", y="Age", data=sales_customer_product, color='red')
plt.title('Interaction type vs Age', fontsize=14)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)

# 3. Grafik: Interaction type vs Discount Applied
plt.subplot(3, 2, 3)  # 3 satır, 2 sütunluk bir yapıdaki 3. grafik
sns.lineplot(x="Interaction type", y="Discount Applied", data=sales_customer_product, color='green')
plt.title('Interaction type vs Discount Applied', fontsize=14)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)

# 4. Grafik: Interaction type vs Frequency of Purchases
plt.subplot(3, 2, 4)  # 3 satır, 2 sütunluk bir yapıdaki 4. grafik
sns.lineplot(x="Interaction type", y="Frequency of Purchases", data=sales_customer_product, color='orange')
plt.title('Interaction type vs Frequency of Purchases', fontsize=14)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)

# 5. Grafik: Interaction type vs Review Rating
plt.subplot(3, 2, 5)  # 3 satır, 2 sütunluk bir yapıdaki 5. grafik
sns.lineplot(x="Interaction type", y="Review Rating", data=sales_customer_product, color='purple')
plt.title('Interaction type vs Review Rating', fontsize=14)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)

# 6. Grafik: Interaction type vs Shipping Weight
plt.subplot(3, 2, 6)  # 3 satır, 2 sütunluk bir yapıdaki 6. grafik
sns.lineplot(x="Interaction type", y="Shipping Weight", data=sales_customer_product, color='brown')
plt.title('Interaction type vs Shipping Weight', fontsize=14)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)

plt.tight_layout()  # Grafiklerin düzenini sıkıştırarak daha düzgün bir görünüm sağlar
plt.show()

# %% [markdown]
# <h1 style="color: #907ad6"> 5. Steps to Improve the Performance of a Machine Learning Model Using Feature Selection and Feature Engineering 🔧📊📈</h1>
#
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p>To enhance the performance of a machine learning model, you can apply Feature Selection and Feature Engineering techniques. Below are the steps in chronological order:</p
#     <h3 style="color: #907ad6">1. Data Inspection and Cleaning (Data Cleaning)</h3>
#     <div style="background-color: #d8c1f7; padding: 10px; border-radius: 5px;">
#         <p>This step should always be done first before building the model.</p>
#         <h4>Inspect the Dataset:</h4>
#         <ul>
#             <li>Analyze data types and missing values.</li>
#             <li>Identify numerical and categorical columns.</li>
#         </ul>
#     </div>
# </div>

# %%
# Get general information about the dataset
print(sales_customer_product.info())

# Check for missing values
print(sales_customer_product.isnull().sum())

# Select numerical columns
numeric_columns = sales_customer_product.select_dtypes(include=['number']).columns
print(f"Numerical Columns: {numeric_columns}")

# Select categorical columns
categorical_columns = sales_customer_product.select_dtypes(exclude=['number']).columns
print(f"Categorical Columns: {categorical_columns}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2999 entries, 0 to 2998
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user id                 2999 non-null   float64
#  1   product id              2999 non-null   object
#  2   Interaction type        2999 non-null   object
#  3   Time stamp              2999 non-null   datetime64[ns]
#  4   Customer ID             2999 non-null   int64
#  5   Age                     2999 non-null   int64
#  6   Gender                  2999 non-null   object
#  7   Item Purchased          2999 non-null   object
#  8   Category_x              2999 non-null   object
#  9   Purchase Amount (USD)   2999 non-null   int64
#  10  Location                2999 non-null   object
#  11  Size                    2999 non-null   object
#  12  Color                   2999 non-null   object
#  13  Season                  2999 non-null   object
# ...

# %% [markdown]
# <h3 style="color: #907ad6"> Dataset Backup</h3>
# <div style="background-color:#e7d8f7;; padding: 10px; border-radius: 5px;">
#     <p>Before making any changes to the dataset, we create a backup for security purposes. This ensures that we can revert to the original data if necessary.</p>
# </div>

# %%
# Create a backup of the dataset
sales_customer_product_copy = sales_customer_product.copy()

# %% [markdown]
# <h2 style="color: #907ad6">5.1 Feature Engineering ⚙️</h2>
# <div style="background-color:#e7d8f7;; padding: 10px; border-radius: 5px;">
#     <h4>Objective:</h4>
#     <p>The aim is to transform the data so that the model can learn more effectively. During this stage, operations are performed on the selected features to create more meaningful and new features or to make the data suitable (normalization, log transformation, etc.).</p>
#     <h4>Methods:</h4>
#     <ul>
#         <li><strong>Normalization and Standardization:</strong> To solve problems caused by different scales of data.</li>
#         <li><strong>One-Hot Encoding:</strong> To convert categorical data into numerical values.</li>
#         <li><strong>Feature Construction:</strong> To create new features (e.g., age ranges, purchase frequencies, etc.).</li>
#         <li><strong>Binning:</strong> To convert numerical data into categorical data.</li>
#         <li><strong>Log Transformations:</strong> To bring data closer to a normal distribution.</li>
#     </ul>
# </div>

# %% [markdown]
# <h3 style="color: #907ad6">Processing of Numerical Features 🔢</h3>
# <div style="background-color:#e7d8f7;; padding: 10px; border-radius: 5px;">
#     <p>Some numerical columns (e.g., Age, Purchase Amount (USD), Review Rating, Previous Purchases, Hour) can be directly included in the model. However, columns like <strong>Purchase Amount (USD)</strong> are features that need to be scaled.</p>
#     <h4>Steps:</h4>
#     <ul>
#         <li><strong>Scaling Numerical Data:</strong> Numerical data is scaled using <code>StandardScaler</code> or <code>MinMaxScaler</code>. This allows the model to work more efficiently and quickly.</li>
#     </ul>
# </div>

# %%
from sklearn.preprocessing import StandardScaler

# Create a copy of the original dataset
sales_customer_product_copy = sales_customer_product.copy()

# Select numeric columns
numeric_columns = sales_customer_product_copy.select_dtypes(include=['number']).columns

# Scaling process
scaler = StandardScaler()
sales_customer_product_copy[numeric_columns] = scaler.fit_transform(sales_customer_product_copy[numeric_columns])

# Now the numeric data in 'sales_customer_product_copy' has been scaled

# %% [markdown]
# <h3 style="color: #907ad6">Processing of Categorical Features 🔄</h3>
# <div style="background-color:#e7d8f7;; padding: 10px; border-radius: 5px;">
#     <p>Categorical data must be converted into numerical data so that the model can process it. One common approach is to use <strong>One-Hot Encoding.</strong></p>
#     <h4>Steps:</h4>
#     <ul>
#         <li><strong>Converting Categorical Features using One-Hot Encoding:</strong> Categorical columns are converted into numerical data using <code>pd.get_dummies()</code>.</li>
#     </ul>
# </div>

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Create a copy of the original dataset
sales_customer_product_copy = sales_customer_product.copy()

# Select numeric columns and apply scaling (from the previous step)
numeric_columns = sales_customer_product_copy.select_dtypes(include=['number']).columns
scaler = StandardScaler()
sales_customer_product_copy[numeric_columns] = scaler.fit_transform(sales_customer_product_copy[numeric_columns])

# Select categorical columns
categorical_columns = sales_customer_product_copy.select_dtypes(include=['object']).columns

# Apply One-Hot Encoding
sales_customer_product_copy = pd.get_dummies(sales_customer_product_copy, columns=categorical_columns)

# Now 'sales_customer_product_copy' has both standardization and One-Hot Encoding applied

# %% [markdown]
# <h3 style="color: #907ad6">Feature Construction 🔧</h3>
# <div style="background-color:#e7d8f7;; padding: 10px; border-radius: 5px;">
#     <p>You can create more meaningful features in your dataset. For example:</p>
#     <ul>
#         <li><strong>Creating Age Groups:</strong> Dividing the <code>Age</code> column into categories can help the model learn better.</li>
#         <li><strong>Purchase Frequency:</strong> A new feature representing the customer's shopping habits can be created using the <code>Purchase Amount (USD)</code> and <code>Previous Purchases</code> columns.</li>
#     </ul>
# </div>

# %%
# Age Groups
bins = [0, 18, 30, 40, 50, 60, 100]
labels = ['0-18', '19-30', '31-40', '41-50', '51-60', '60+']
sales_customer_product_copy['Age Group'] = pd.cut(sales_customer_product_copy['Age'], bins=bins, labels=labels)

# Purchase Frequency (e.g., based on previous purchase count)
sales_customer_product_copy['Purchase Frequency'] = sales_customer_product_copy['Previous Purchases'] / sales_customer_product_copy['Purchase Amount (USD)']

# Now the dataset includes new features like 'Age Group' and 'Purchase Frequency'

# %% [markdown]
# <h3 style="color: #907ad6"> Binning (Feature Grouping) 📊</h3>
# <div style="background-color:#e7d8f7; ; padding: 10px; border-radius: 5px;">
#     <p>Converting numerical data into categorical data can be useful in some cases. For example, by dividing columns like <code>Review Rating</code> into specific ranges, you can make it easier for the model to understand.</p>
# </div>

# %%
# Review Rating Binning
review_bins = [0, 2, 4, 5]
review_labels = ['Low', 'Medium', 'High']
sales_customer_product_copy['Review Rating Group'] = pd.cut(sales_customer_product_copy['Review Rating'], bins=review_bins, labels=review_labels)

# Now there is a new feature called 'Review Rating Group'

# %% [markdown]
# <h2 style="color: #907ad6">5.2 Feature Selection 🧩 </h2>
# <div style="background-color:#e7d8f7;; padding: 10px; border-radius: 5px;">
#     <p><strong>Objective:</strong></p>
#     <ul>
#         <li><strong>Reduce the Dataset:</strong> Train the model with more meaningful features.</li>
#         <li><strong>Avoid Overfitting:</strong> Prevent the model from overfitting by removing unnecessary or highly correlated features.</li>
#         <li><strong>Speed and Efficiency:</strong> Reducing the number of features shortens training time and increases model efficiency.</li>
#     </ul>
#     <p><strong>Methods:</strong></p>
#     <ul>
#         <li><strong>Correlation-Based Selection:</strong> Examine correlations between features and remove those that have high correlation.</li>
#         <li><strong>Feature Importance Scores:</strong> Model-based selections (e.g., feature importance scores from models like Random Forest, XGBoost).</li>
#         <li><strong>Recursive Feature Elimination (RFE):</strong> A method that removes features one by one.</li>
#         <li><strong>Removing Redundant Features:</strong> Columns that provide the same or very similar information can be removed.</li>
#     </ul>
# </div>

# %% [markdown]
# <h3 style="color: #907ad6">Correlation-Based Selection 🔗</h3>
# <div style="background-color:#e7d8f7; ; padding: 10px; border-radius: 5px;">
#     <p>By detecting high correlations between features, we can remove those that are very similar. This helps reduce the complexity of the model.</p>
#     <p><strong>Steps:</strong></p>
#     <ul>
#         <li>Examine columns with high correlation and set a threshold (e.g., remove features with a correlation of 0.8 or higher).</li>
#     </ul>
# </div>

# %%
# Create a copy of the data
sales_customer_product_corr = sales_customer_product.copy()

# Select numeric columns
numeric_columns = sales_customer_product_corr.select_dtypes(include=['number']).columns

# Calculate the correlation matrix
corr_matrix = sales_customer_product_corr[numeric_columns].corr()

# Visualize the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix")
plt.show()

# Select features with high correlation (excluding its own column)
threshold = 0.8  # Correlation threshold
high_corr_features = [col for col in corr_matrix.columns if any(corr_matrix[col] > threshold) and col != corr_matrix.columns[corr_matrix[col].argmax()]]

# Remove features with high correlation from the dataset
sales_customer_product_corr = sales_customer_product_corr.drop(columns=high_corr_features)

# Print the removed high correlation features
print(f"Removed high correlation features: {high_corr_features}")
# Out:
# Removed high correlation features: ['Customer ID']

# %% [markdown]
# <h3 style="color: #907ad6">Feature Selection Based on Feature Importance ⚡</h3>
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p><strong>Explanation:</strong></p>
#     <ul>
#         <li><strong>Feature Importance:</strong> Feature importance refers to the contribution of each feature to the prediction of the target variable. After training a model, such as Random Forest or XGBoost, we can calculate the importance of each feature based on how much it helps in reducing prediction error.</li>
#         <li><strong>Reduce Model Complexity:</strong> Not all features contribute equally to the model's performance. Features with low importance can be removed to reduce model complexity, making it simpler and more interpretable. A simpler model also helps to avoid overfitting, where the model learns too much from noise or irrelevant features.</li>
#         <li><strong>Efficiency:</strong> Removing less important features reduces the number of variables that the model has to process, which in turn speeds up training time. It also reduces the computational resources required for model training, making the model more efficient overall.</li>
#     </ul>
#     <p><strong>Why it's done:</strong></p>
#     <ul>
#         <li>By identifying and removing less important features, we ensure that the model focuses only on the most relevant data, improving both its predictive power and interpretability.</li>
#         <li>This process helps improve the model’s accuracy by preventing it from relying on unnecessary or noisy features that could hinder its ability to generalize well to unseen data.</li>
#         <li>Optimizing model performance and reducing overfitting are key goals in machine learning, and feature selection based on importance helps achieve both of these goals effectively.</li>
#     </ul>
#     <p><strong>Steps to Implement:</strong></p>
#     <ul>
#         <li><strong>Train a Model:</strong> Use models like Random Forest or XGBoost, which can calculate feature importance based on their internal structure.</li>
#         <li><strong>Calculate Feature Importance:</strong> Once the model is trained, obtain the feature importance scores, which rank features according to how much they contribute to the prediction.</li>
#         <li><strong>Remove Low Importance Features:</strong> Based on the calculated importance scores, remove the features with low importance, keeping only those that significantly contribute to the model’s performance.</li>
#     </ul>
# </div>
# </ul>
# </div>

# %% [markdown]
# <h3 style="color: #907ad6">Encoding Categorical Features 🧑‍💻</h3>
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p><strong>Explanation:</strong></p>
#     <ul>
#         <li><strong>Categorical Features:</strong> Categorical variables (such as "Gender", "Region", etc.) need to be converted into numerical data before they can be used in a model.</li>
#         <li><strong>One-Hot Encoding:</strong> This method creates a binary column for each category in a feature, allowing the model to interpret categorical data as separate variables.</li>
#         <li><strong>Label Encoding:</strong> Another method where each category is assigned a unique integer, often used when the categories have an inherent order.</li>
#     </ul>
#     <p><strong>Why it's done:</strong></p>
#     <ul>
#         <li>Machine learning models typically work with numerical data, so transforming categorical features into numbers is crucial for successful model training.</li>
#     </ul>
# </div>

# %%
print(sales_customer_product_copy.columns)
# Out:
# Index(['user id', 'Time stamp', 'Customer ID', 'Age', 'Purchase Amount (USD)',
#        'Review Rating', 'Previous Purchases', 'Hour',
#        'product id_0000fe97fd6c7705b08b7f4c7c5312ce',
#        'product id_00037729f1cb566e149f0beff2d9ffd3',
#        ...
#        'Day_Friday', 'Day_Monday', 'Day_Saturday', 'Day_Sunday',
#        'Day_Thursday', 'Day_Tuesday', 'Day_Wednesday', 'Age Group',
#        'Purchase Frequency', 'Review Rating Group'],
#       dtype='object', length=29152)

# %%
from sklearn.preprocessing import LabelEncoder

# Identify categorical columns
categorical_columns = sales_customer_product_copy.select_dtypes(include=['object']).columns
print("Categorical columns:", categorical_columns)

# Label Encoding: If no ordering is required
label_encoder = LabelEncoder()

# Transform categorical columns
for col in categorical_columns:
    sales_customer_product_copy[col] = label_encoder.fit_transform(sales_customer_product_copy[col])

# Check the transformations
print(sales_customer_product_copy.head())
# Out:
# Categorical columns: Index([], dtype='object')
#     user id          Time stamp  Customer ID       Age  Purchase Amount (USD)  \
# 0 -1.731473 2023-10-10 08:00:00    -1.731473  0.715594              -0.279591
# 1 -1.730318 2023-10-11 08:00:00    -1.730318 -1.640060               0.182667
# 2 -1.729163 2023-10-12 08:00:00    -1.729163  0.388420               0.560877
# 3 -1.728008 2023-10-13 08:00:00    -1.728008 -1.509191               1.275275
# 4 -1.726853 2023-10-14 08:00:00    -1.726853  0.061246              -0.447684
#
#    Review Rating  Previous Purchases      Hour  \
# 0      -0.909532           -0.808334 -0.743533
# 1      -0.909532           -1.641152 -0.743533
# 2      -0.909532           -0.183721 -0.743533
# 3      -0.349633            1.620718 -0.743533
# 4      -1.469430            0.371491 -0.743533
#
#    product id_0000fe97fd6c7705b08b7f4c7c5312ce  \
# 0                                        False
# 1                                        False
# ...

# %% [markdown]
# <h3 style="color: #907ad6">2. Model Independent and Target Variable Selection 🔑</h3>
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p><strong>Explanation:</strong></p>
#     <ul>
#         <li><strong>Target Variable:</strong> The output the model predicts. In classification, it’s typically categorical (e.g., <em>Interaction type</em>, <em>Purchase Amount (USD)</em>).</li>
#         <li><strong>Independent Variables:</strong> Inputs used to predict the target. Select variables strongly correlated with the target to ensure accurate predictions.</li>
#     </ul>
#     <p><strong>Why?</strong></p>
#     <ul>
#         <li>Correct target selection ensures the model solves the right problem.</li>
#         <li>Proper independent variable selection improves model efficiency and prediction accuracy.</li>
#     </ul>
#     <p><strong>How:</strong></p>
#     <ul>
#         <li><strong>Target Variable:</strong> Choose the variable to predict (e.g., <em>Interaction type</em>).</li>
#         <li><strong>Independent Variables:</strong> Select features that help predict the target variable.</li>
#     </ul>
# </div>
#     </ul>
# </div>

# %%
# Check all column names in the dataset
print(sales_customer_product_copy.columns)
# Out:
# Index(['user id', 'Time stamp', 'Customer ID', 'Age', 'Purchase Amount (USD)',
#        'Review Rating', 'Previous Purchases', 'Hour',
#        'product id_0000fe97fd6c7705b08b7f4c7c5312ce',
#        'product id_00037729f1cb566e149f0beff2d9ffd3',
#        ...
#        'Day_Friday', 'Day_Monday', 'Day_Saturday', 'Day_Sunday',
#        'Day_Thursday', 'Day_Tuesday', 'Day_Wednesday', 'Age Group',
#        'Purchase Frequency', 'Review Rating Group'],
#       dtype='object', length=29152)

# %%
# Define the target variable (y) as 'Review Rating Group'
y = sales_customer_product_copy['Review Rating Group']

# Define the independent variables (X) by dropping the 'Review Rating Group' column
X = sales_customer_product_copy.drop(columns=['Review Rating Group'])

# %% [markdown]
# <h3 style="color: #907ad6">Feature Creation ✨</h3>
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p><strong>Explanation:</strong></p>
#     <ul>
#         <li><strong>Enhance Model Understanding:</strong> Create new features from existing ones to capture more meaningful patterns.</li>
#         <li><strong>Time-Based Features:</strong> Break down date or time into components like hour, day, or year to reveal trends.</li>
#         <li><strong>Transform Continuous Variables:</strong> Convert variables like age or purchase amounts into categories (e.g., age ranges, purchase frequency).</li>
#     </ul>
#     <p><strong>Why?</strong></p>
#     <ul>
#         <li>Improves model's predictive power by adding meaningful context.</li>
#         <li>Helps with interpretability and pattern recognition.</li>
#     </ul>
# </div>

# %% [markdown]
# <h4 style="color: #907ad6">1.Time Related Features ⏳</h4>
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p><strong>Explanation:</strong></p>
#     <ul>
#         <li><strong>Time Period Extraction:</strong> Deriving features such as Day, Week, Month, and Year can help understand patterns in user behavior over time. For example, identifying shopping habits based on specific timeframes can be insightful.</li>
#     </ul>
# </div>

# %%
# Extracting time-based features from the 'Time stamp' column

# Year: Extracts the year from the 'Time stamp' column
sales_customer_product['Year'] = sales_customer_product['Time stamp'].dt.year

# Month: Extracts the month (1 to 12) from the 'Time stamp' column
sales_customer_product['Month'] = sales_customer_product['Time stamp'].dt.month

# Weekday: Extracts the day of the week (0 = Monday, 6 = Sunday) from the 'Time stamp' column
sales_customer_product['Weekday'] = sales_customer_product['Time stamp'].dt.weekday

# Hour_of_day: Extracts the hour of the day (0 to 23) from the 'Time stamp' column
sales_customer_product['Hour_of_day'] = sales_customer_product['Time stamp'].dt.hour

# %% [markdown]
# <h4 style="color: #907ad6">2. Weekday/Weekend Information 📅</h4>
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p><strong>Explanation:</strong></p>
#     <ul>
#         <li><strong>Weekday/Weekend Analysis:</strong> You can use the Weekday value to analyze shopping differences between weekdays and weekends. This helps in understanding how consumer behavior varies across different days of the week.</li>
#     </ul>
# </div>

# %%
# Assign 'Weekend' or 'Weekday' based on the 'Weekday' column
sales_customer_product['Weekend'] = sales_customer_product['Weekday'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Weekend', data=sales_customer_product, palette='Set2')
plt.title('Hafta içi ve Hafta Sonu Satış Dağılımı', fontsize=14)
plt.xlabel('Zaman Dilimi', fontsize=12)
plt.ylabel('Satış Sayısı', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4 style="color: #907ad6">3. Sales Analysis by Age Groups 🧑‍🤝‍🧑</h4>
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p><strong>Explanation:</strong></p>
#     <ul>
#         <li><strong>Age Grouping:</strong> Grouping age data and analyzing sales for each group can help you understand the target audience better. By creating age ranges, you can identify purchasing trends and preferences across different age categories.</li>
#     </ul>
# </div>

# %%
# Check unique values in the 'Age' column
print(sales_customer_product['Age'].unique())
# Out:
# [55 19 50 21 45 46 63 27 26 57 53 30 61 65 64 25 52 66 31 56 18 38 54 33
#  36 35 29 70 69 67 20 39 42 68 49 59 47 40 41 48 22 24 44 37 58 32 62 51
#  28 43 34 23 60]

# %%
# Histogram of Age distribution
plt.figure(figsize=(10, 6))
sns.histplot(sales_customer_product['Age'], kde=True, bins=30, color='skyblue')
plt.title('Age Distribution - Histogram', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.tight_layout()
plt.show()

# Boxplot of Age distribution
plt.figure(figsize=(10, 6))
sns.boxplot(x=sales_customer_product['Age'], color='lightgreen')
plt.title('Age Distribution - Boxplot', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4 style="color: #907ad6">4. Purchase Amount and Review Rating 💳</h4>
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p><strong>Explanation:</strong></p>
#     <ul>
#         <li><strong>Purchase Amount and Review Rating Analysis:</strong> Analyzing numerical columns like purchase amounts and review ratings can reveal patterns in consumer behavior. These columns can be grouped over time or by different categories to identify trends in customer spending and satisfaction.</li>
#     </ul>
# </div>

# %%
# Feature for frequent buyers analysis
sales_customer_product['Repeat_Buyer'] = sales_customer_product['Previous Purchases'].apply(lambda x: 'Yes' if x > 0 else 'No')

# Count of repeat buyers
plt.figure(figsize=(10, 6))
sns.countplot(x='Repeat_Buyer', data=sales_customer_product, palette='Set2')
plt.title('Repeat Buyer Distribution', fontsize=14)
plt.xlabel('Repeat Purchase', fontsize=12)
plt.ylabel('Number of Sales', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1 style="color: #907ad6">6. Results and Recommendations 💬🌐  </h1>
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p><strong>Summary:</strong></p>
#     <p>In this study, we performed a comprehensive data analysis by merging three different datasets: Sales Data, Customer Details, and Product Details. These datasets provide insights into customer behavior and product interactions within an e-commerce environment. Through data merging and exploratory data analysis (EDA), relationships between customer profiles, purchasing tendencies, product features, and sales data were analyzed, resulting in valuable insights that can aid the company's decision-making processes.</p
#     <p><strong>Problem and Solution Scenarios:</strong></p>
#     <p>Based on this analysis, the dataset can provide solutions to various problems. For example, in an e-commerce company, this data can be used for the following purposes:</p>
#     <ul>
#         <li><strong>Purchase Behavior Prediction:</strong> This data can be used to predict which products customers are likely to purchase, how frequently, and at which times. This enables the company to anticipate customer behavior and create personalized campaigns. Additionally, based on previous customer interactions, cross-selling and recommendation systems can be developed.</li>
#         <li><strong>Stock and Inventory Management:</strong> Sales data can be used to optimize stock management. Future demand can be predicted based on the sales trends of popular products, ensuring timely stock replenishment. Moreover, detecting seasonal sales spikes can lead to better planning to address seasonal demands.</li>
#         <li><strong>Targeted Advertising and Marketing:</strong> By analyzing the relationship between customer demographics and purchasing behavior, personalized marketing strategies can be developed for specific customer segments. For instance, products that are more popular among certain age groups or regions can be identified, and targeted advertisements can be delivered to those customers.</li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style="color: #907ad6">6.1 Algorithm and Model Recommendations 🤖</h2>
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p><strong>Explanation:</strong></p>
#     <ul>
#         <li><strong>Random Forest 📊:</strong> This algorithm performs well on high-dimensional and complex datasets. It can also be used for feature selection, providing insights into which features the model relies on. Random Forest typically delivers effective results in e-commerce sales predictions.</li>
#         <li><strong>Gradient Boosting (XGBoost) 🚀:</strong> XGBoost is highly successful on large datasets and classification problems, providing high accuracy. It benefits from improvements in feature engineering, helping to enhance the model's performance further.</li>
#         <li><strong>Logistic Regression ⚙️:</strong> Although simple, Logistic Regression can deliver quick and efficient results, particularly in classification tasks. It is especially useful for classifying user interactions.</li>
#         <li><strong>Neural Networks (DNN) 🧠:</strong> For large datasets with complex relationships, deep learning models (DNNs) can be applied. These models tend to provide high performance, but they require more computational power and time due to their large number of parameters and data reliance.</li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style="color: #907ad6">6.2 Insights 💡</h2 >
# <div style="background-color: #e7d8f7; padding: 10px; border-radius: 5px;">
#     <p><strong>Feature Selection and Data Cleaning 🧹:</strong></p>
#     <ul>
#         <li>Feature selection and data cleaning are essential steps for preparing the dataset. Removing irrelevant or missing data will enhance the dataset's quality, making future model development more efficient.</li>
#     </ul>
#
# <p><strong>Time Series Analysis and Product-Trend Relationship 📈:</strong></p>
#     <ul>
#         <li>Analyzing time-related features such as day, week, or holidays provides valuable insights into sales trends. These initial findings will be helpful in shaping the future modeling approach.</li>
#     </ul>
#
# <p><strong>Personalized Marketing and Segmentation 🎯:</strong></p>
#     <ul>
#         <li>Customer segmentation based on available data can help identify purchasing patterns. This allows for more targeted marketing strategies and provides useful insights into customer behavior.</li>
#     </ul>
#
# <p><strong>Hyperparameter Optimization ⚙️:</strong></p>
#     <ul>
#         <li>Hyperparameter optimization applies after building and training a model. Since no model has been created yet, this step will be relevant once the model development begins.</li>
#     </ul>
#
# <p><strong>Suggestion:</strong></p>
#     <ul>
#      <li>At this stage, the focus should be on analyzing the data and gaining insights from it. These insights will form the foundation for building and optimizing future models.</li>
#     </ul>
# </div>
